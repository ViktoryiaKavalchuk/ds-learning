# %%
import pandas

column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

data = pandas.read_csv("/Users/Viktoryia/Documents/Programming/Data_Science/Lesson_6/boston_dataset.csv", delimiter=r"\s+", names=column_names)
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
import numpy

#data['MEDV CRIM'] = data['MEDV'] / data['CRIM']
#crim_medv = data['MEDV CRIM']
#crim_medv

#print(float(numpy.median(crim_medv)))
#print(float(numpy.quantile(data['CRIM'], 0.25)))

# %%
table = data.describe()
table
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#найти коэфициенты, без линейной регрессии и производной

quantile_step_percent = 5
row_headers = [f"{step}%" for step in range(quantile_step_percent, 101, quantile_step_percent)]

quantile_list = []
for column_name in column_names:
    row = []
    for quantile in numpy.arange(0, 1, quantile_step_percent / 100):
        value = float(numpy.quantile(data[column_name], quantile))
        row.append(value)
    quantile_list.append(row)

quantile_table = pandas.DataFrame(quantile_list, index=column_names, columns=row_headers).T.map(lambda x: f"{x:.6f}")

quantile_table
# Out:
#            CRIM         ZN      INDUS      CHAS       NOX        RM  \
# 5%     0.006320   0.000000   0.460000  0.000000  0.385000  3.561000
# 10%    0.027910   0.000000   2.180000  0.000000  0.409250  5.314000
# 15%    0.038195   0.000000   2.910000  0.000000  0.427000  5.593500
# 20%    0.050770   0.000000   3.640000  0.000000  0.436500  5.712000
# 25%    0.064170   0.000000   4.390000  0.000000  0.442000  5.837000
# 30%    0.082045   0.000000   5.190000  0.000000  0.449000  5.885500
# 35%    0.099245   0.000000   5.960000  0.000000  0.472000  5.950500
# 40%    0.125165   0.000000   6.200000  0.000000  0.489000  6.008250
# 45%    0.150380   0.000000   7.380000  0.000000  0.507000  6.086000
# 50%    0.192743   0.000000   8.140000  0.000000  0.520000  6.144000
# 55%    0.256510   0.000000   9.690000  0.000000  0.538000  6.208500
# 60%    0.352032   0.000000  10.010000  0.000000  0.544000  6.284250
# 65%    0.550070   0.000000  12.830000  0.000000  0.575000  6.376000
# ...

# %% [markdown]
# CRIM - per capita crime rate by town
#     - moderate negative (-0.39) influence (70% has low value)
#
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#     - moderate positive (0.36) influence (75% has 0 value, the other have values starting from 12 till 80)
#
# INDUS - proportion of non-retail business acres per town.
#     - strong negative (-0.48) influence (but 30% has no big change in value)
#
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#     - light positive (0.18) influence (95% has 0 value)
#
# NOX - nitric oxides concentration (parts per 10 million)
#     - strong negative (-0.43) influence
#
# RM - average number of rooms per dwelling
#     - very strong positive (0.70) influence
#
# AGE - proportion of owner-occupied units built prior to 1940
#     - moderate negative (-0.38) influence
#
# DIS - weighted distances to five Boston employment centres
#     - less moderate positive (0.25) influence
#
# RAD - index of accessibility to radial highways
#     - moderate negative (-0.38) influence
#
# TAX - full-value property-tax rate per $10,000
#     - strong negative (-0.47) influence
#
# PTRATIO - pupil-teacher ratio by town
#     - strong negative (-0.51) influence
#
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#     - moderate positive (0.33) influence
#
# LSTAT - % lower status of the population
#     - very strong negative (-0.74) influence
#
# ---------------------------------------------------------------------------
#
# MEDV - Median value of owner-occupied homes in $1000's

# %%
zn_greater_0 = data[data['ZN'] > 0]
print(len(zn_greater_0))

chas_greater_0 = data[data['CHAS'] > 0]
print(len(chas_greater_0))
# Out:
# 134
# 35

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_dict = {}

def build_parameter_dependency_graph(x_column: str):
    sns.regplot(x=x_column, y=data['MEDV'], data=data, scatter_kws={'alpha':0.6})
    
    correlation = data[x_column].corr(data['MEDV'])
    print(f"{x_column} -> MEDV correlation: {correlation:.2f}")

    correlation_dict.setdefault(x_column, round(float(correlation), 2))

# %%
x_column = 'CRIM'
build_parameter_dependency_graph(x_column)
# Out:
# CRIM -> MEDV correlation: -0.39

# %%
x_column = 'ZN'
build_parameter_dependency_graph(x_column)
# Out:
# ZN -> MEDV correlation: 0.36

# %%
x_column = 'INDUS'
build_parameter_dependency_graph(x_column)
# Out:
# INDUS -> MEDV correlation: -0.48

# %%
x_column = 'CHAS'
build_parameter_dependency_graph(x_column)
# Out:
# CHAS -> MEDV correlation: 0.18

# %%
x_column = 'NOX'
build_parameter_dependency_graph(x_column)
# Out:
# NOX -> MEDV correlation: -0.43

# %%
x_column = 'RM'
build_parameter_dependency_graph(x_column)
# Out:
# RM -> MEDV correlation: 0.70

# %%
x_column = 'AGE'
build_parameter_dependency_graph(x_column)
# Out:
# AGE -> MEDV correlation: -0.38

# %%
x_column = 'DIS'
build_parameter_dependency_graph(x_column)
# Out:
# DIS -> MEDV correlation: 0.25

# %%
x_column = 'RAD'
build_parameter_dependency_graph(x_column)
# Out:
# RAD -> MEDV correlation: -0.38

# %%
x_column = 'TAX'
build_parameter_dependency_graph(x_column)
# Out:
# TAX -> MEDV correlation: -0.47

# %%
x_column = 'PTRATIO'
build_parameter_dependency_graph(x_column)
# Out:
# PTRATIO -> MEDV correlation: -0.51

# %%
x_column = 'B'
build_parameter_dependency_graph(x_column)
# Out:
# B -> MEDV correlation: 0.33

# %%
x_column = 'LSTAT'
build_parameter_dependency_graph(x_column)
# Out:
# LSTAT -> MEDV correlation: -0.74

# %%
# ABS correlation for each parameter sorted descengingly to show the range from the most strong parameters till the weakest ones

dict(
    sorted(
        correlation_dict.items(),
        key=lambda item: abs(item[1]),
        reverse=True
    )
)
# Out:
# {'LSTAT': -0.74,
#  'RM': 0.7,
#  'PTRATIO': -0.51,
#  'INDUS': -0.48,
#  'TAX': -0.47,
#  'NOX': -0.43,
#  'CRIM': -0.39,
#  'AGE': -0.38,
#  'RAD': -0.38,
#  'ZN': 0.36,
#  'B': 0.33,
#  'DIS': 0.25,
#  'CHAS': 0.18}

# %%
#AI proposal


lstat = numpy.array(data['LSTAT'])
rm = numpy.array(data['RM'])
ptratio = numpy.array(data['PTRATIO'])
indus = numpy.array(data['INDUS'])
tax = numpy.array(data['TAX'])
nox = numpy.array(data['NOX'])
crim = numpy.array(data['CRIM'])
age = numpy.array(data['AGE'])
rad = numpy.array(data['RAD'])
zn = numpy.array(data['ZN'])
b = numpy.array(data['B'])
dis = numpy.array(data['DIS'])
chas = numpy.array(data['CHAS'])

medv = numpy.array(data['MEDV'])

bias_ratio = numpy.ones_like(medv)
feature_matrix = numpy.column_stack(
    (
        lstat,
        rm,
        ptratio,
        indus,
        tax,
        nox,
        crim,
        age,
        rad,
        zn,
        b,
        dis,
        chas,
        bias_ratio
    )
)
theta = numpy.linalg.inv(feature_matrix.T @ feature_matrix) @ feature_matrix.T @ medv

lstat_ratio, rm_ratio, ptratio_ratio, indus_ratio, tax_ratio, nox_ratio, crim_ratio, age_ratio, rad_ratio, zn_ratio, b_ratio, dis_ratio, chas_ratio, bias_ratio_ratio = theta

print(
    f"lstat_ratio =\t\t{lstat_ratio},\n"
    f"rm_ratio =\t\t{rm_ratio},\n"
    f"ptratio_ratio =\t\t{ptratio_ratio},\n"
    f"indus_ratio =\t\t{indus_ratio},\n"
    f"tax_ratio =\t\t{tax_ratio},\n"
    f"nox_ratio =\t\t{nox_ratio},\n"
    f"crim_ratio =\t\t{crim_ratio},\n"
    f"age_ratio =\t\t{age_ratio},\n"
    f"rad_ratio =\t\t{rad_ratio},\n"
    f"zn_ratio =\t\t{zn_ratio},\n"
    f"b_ratio =\t\t{b_ratio},\n"
    f"dis_ratio =\t\t{dis_ratio},\n"
    f"chas_ratio =\t\t{chas_ratio},\n"
    f"bias_ratio_ratio =\t{bias_ratio_ratio}"
)
# Out:
# lstat_ratio =		-0.5247583778554131,
# rm_ratio =		3.8098652068107737,
# ptratio_ratio =		-0.9527472317069836,
# indus_ratio =		0.02055862636723532,
# tax_ratio =		-0.012334593916576153,
# nox_ratio =		-17.76661122830285,
# crim_ratio =		-0.10801135783679783,
# age_ratio =		0.0006922246403512824,
# rad_ratio =		0.30604947898516677,
# zn_ratio =		0.04642045836688583,
# b_ratio =		0.009311683273797371,
# dis_ratio =		-1.475566845599952,
# chas_ratio =		2.6867338193449957,
# bias_ratio_ratio =	36.45948838507093

# %%
def calculate_house_price(lstat: float, rm: float, ptratio: float, indus: float, tax: float, nox: float, crim: float, age: float, rad: float, zn: float, b: float, dis: float, chas: float) -> float:
    return float(
        lstat_ratio * lstat 
        + rm_ratio * rm 
        + ptratio_ratio * ptratio
        + indus_ratio * indus
        + tax_ratio * tax
        + nox_ratio * nox
        + crim_ratio * crim
        + age_ratio * age
        + rad_ratio * rad
        + zn_ratio * zn
        + b_ratio * b
        + dis_ratio * dis
        + chas_ratio * chas
        + bias_ratio_ratio
    )

data['MEDV_PREDICTED'] = data.apply(
    lambda row: calculate_house_price(
        row['LSTAT'], row['RM'], row['PTRATIO'], row['INDUS'], row['TAX'],
        row['NOX'], row['CRIM'], row['AGE'], row['RAD'], row['ZN'],
        row['B'], row['DIS'], row['CHAS']
    ),
    axis=1
)

data['MEDV - MEDV_PREDICTED'] = (data['MEDV'] - data['MEDV_PREDICTED']).round(2).abs()
data['MEDV - MEDV_PREDICTED SQUARE'] = (data['MEDV'] - data['MEDV_PREDICTED']).round(2) ** 2
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#AI proposal 2


lstat = numpy.array(data['LSTAT'])
rm = numpy.array(data['RM'])
ptratio = numpy.array(data['PTRATIO'])
indus = numpy.array(data['INDUS'])
tax = numpy.array(data['TAX'])
nox = numpy.array(data['NOX'])
crim = numpy.array(data['CRIM'])
age = numpy.array(data['AGE'])
rad = numpy.array(data['RAD'])
zn = numpy.array(data['ZN'])
b = numpy.array(data['B'])
dis = numpy.array(data['DIS'])

medv = numpy.array(data['MEDV'])

bias_ratio = numpy.ones_like(medv)
feature_matrix = numpy.column_stack(
    (
        lstat,
        rm,
        ptratio,
        indus,
        tax,
        nox,
        crim,
        age,
        rad,
        zn,
        b,
        dis,
        bias_ratio
    )
)
theta = numpy.linalg.inv(feature_matrix.T @ feature_matrix) @ feature_matrix.T @ medv

lstat_ratio, rm_ratio, ptratio_ratio, indus_ratio, tax_ratio, nox_ratio, crim_ratio, age_ratio, rad_ratio, zn_ratio, b_ratio, dis_ratio, bias_ratio_ratio = theta

print(
    f"lstat_ratio =\t\t{lstat_ratio},\n"
    f"rm_ratio =\t\t{rm_ratio},\n"
    f"ptratio_ratio =\t\t{ptratio_ratio},\n"
    f"indus_ratio =\t\t{indus_ratio},\n"
    f"tax_ratio =\t\t{tax_ratio},\n"
    f"nox_ratio =\t\t{nox_ratio},\n"
    f"crim_ratio =\t\t{crim_ratio},\n"
    f"age_ratio =\t\t{age_ratio},\n"
    f"rad_ratio =\t\t{rad_ratio},\n"
    f"zn_ratio =\t\t{zn_ratio},\n"
    f"b_ratio =\t\t{b_ratio},\n"
    f"dis_ratio =\t\t{dis_ratio},\n"
    f"bias_ratio_ratio =\t{bias_ratio_ratio}"
)
# Out:
# lstat_ratio =		-0.534157620403538,
# rm_ratio =		3.850491692482273,
# ptratio_ratio =		-0.9909580312432353,
# indus_ratio =		0.04031145362751075,
# tax_ratio =		-0.013755828844755917,
# nox_ratio =		-17.36699939372241,
# crim_ratio =		-0.11313907811822232,
# age_ratio =		0.0027837565064450735,
# rad_ratio =		0.3283110113832303,
# zn_ratio =		0.04705245779485617,
# b_ratio =		0.00974145093994743,
# dis_ratio =		-1.485373898185165,
# bias_ratio_ratio =	36.891959796909255

# %%
def calculate_house_price(lstat: float, rm: float, ptratio: float, indus: float, tax: float, nox: float, crim: float, age: float, rad: float, zn: float, b: float, dis: float) -> float:
    return float(
        lstat_ratio * lstat 
        + rm_ratio * rm 
        + ptratio_ratio * ptratio
        + indus_ratio * indus
        + tax_ratio * tax
        + nox_ratio * nox
        + crim_ratio * crim
        + age_ratio * age
        + rad_ratio * rad
        + zn_ratio * zn
        + b_ratio * b
        + dis_ratio * dis
        + bias_ratio_ratio
    )

data['MEDV_PREDICTED'] = data.apply(
    lambda row: calculate_house_price(
        row['LSTAT'], row['RM'], row['PTRATIO'], row['INDUS'], row['TAX'],
        row['NOX'], row['CRIM'], row['AGE'], row['RAD'], row['ZN'],
        row['B'], row['DIS']
    ),
    axis=1
)

data['MEDV - MEDV_PREDICTED'] = (data['MEDV'] - data['MEDV_PREDICTED']).round(2).abs()
data['MEDV - MEDV_PREDICTED SQUARE'] = (data['MEDV'] - data['MEDV_PREDICTED']).round(2) ** 2
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...
